# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# Read the input file
df = pd.read_excel('C:\\Users\\Likhith V\\Downloads\\drive-download-20230430T084044Z-001\\input.xlsx')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      URL_ID                                                URL
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
# [114 rows x 2 columns]>

# %%
# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    url_id = row['URL_ID']
    url = row['URL']
    try:
        # Send a GET request to the URL
        response = requests.get(url)

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract the article title
        title = soup.title.string.strip()

        # Find the main article content
        article_content = soup.find('article')

        # Extract the article text
        article_text = ''
        for paragraph in article_content.find_all('p'):
            article_text += paragraph.get_text() + '\n'

        # Save the extracted article as a text file
        with open(f'{url_id}.txt', 'w', encoding='utf-8') as file:
            file.write(f'{title}\n\n{article_text}')

        print(f'Saved {url_id}.txt')
    except Exception as e:
        print(f'Error processing {url_id}: {str(e)}')

print('Extraction completed.')
# Out:
# Saved 37.txt
# Saved 38.txt
# Saved 39.txt
# Saved 40.txt
# Saved 41.txt
# Saved 42.txt
# Saved 43.txt
# Error processing 44: 'NoneType' object has no attribute 'find_all'
# Saved 45.txt
# Saved 46.txt
# Saved 47.txt
# Saved 48.txt
# Saved 49.txt
# Saved 50.txt
# Saved 51.txt
# Saved 52.txt
# Saved 53.txt
# Saved 54.txt
# Saved 55.txt
# Saved 56.txt
# Error processing 57: 'NoneType' object has no attribute 'find_all'
# Saved 58.txt
# Saved 59.txt
# Saved 60.txt
# Saved 61.txt
# Saved 62.txt
# Saved 63.txt
# Saved 64.txt
# Saved 65.txt
# Saved 66.txt
# Saved 67.txt
# Saved 68.txt
# Saved 69.txt
# Saved 70.txt
# Saved 71.txt
# Saved 72.txt
# Saved 73.txt
# Saved 74.txt
# Saved 75.txt
# Saved 76.txt
# Saved 77.txt
# Saved 78.txt
# Saved 79.txt
# Saved 80.txt
# Saved 81.txt
# Saved 82.txt
# Saved 83.txt
# Saved 84.txt
# Saved 85.txt
# Saved 86.txt
# Saved 87.txt
# Saved 88.txt
# Saved 89.txt
# Saved 90.txt
# Saved 91.txt
# Saved 92.txt
# Saved 93.txt
# Saved 94.txt
# Saved 95.txt
# Saved 96.txt
# Saved 97.txt
# Saved 98.txt
# Saved 99.txt
# Saved 100.txt
# Saved 101.txt
# Saved 102.txt
# Saved 103.txt
# Saved 104.txt
# Saved 105.txt
# Saved 106.txt
# Saved 107.txt
# Saved 108.txt
# Saved 109.txt
# Saved 110.txt
# Saved 111.txt
# Saved 112.txt
# Saved 113.txt
# Saved 114.txt
# Saved 115.txt
# Saved 116.txt
# Saved 117.txt
# Saved 118.txt
# Saved 119.txt
# Saved 120.txt
# Saved 121.txt
# Saved 122.txt
# Saved 123.txt
# Saved 124.txt
# Saved 125.txt
# Saved 126.txt
# Saved 127.txt
# Saved 128.txt
# Saved 129.txt
# Saved 130.txt
# Saved 131.txt
# Saved 132.txt
# Saved 133.txt
# Saved 134.txt
# Saved 135.txt
# Saved 136.txt
# Saved 137.txt
# Saved 138.txt
# Saved 139.txt
# Saved 140.txt
# Saved 141.txt
# Saved 142.txt
# Saved 143.txt
# Error processing 144: 'NoneType' object has no attribute 'find_all'
# Saved 145.txt
# Saved 146.txt
# Saved 147.txt
# Saved 148.txt
# Saved 149.txt
# Saved 150.txt
# Extraction completed.
